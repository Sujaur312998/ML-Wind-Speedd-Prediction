# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer


from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,roc_curve, roc_auc_score
import warnings

# %%
df = pd.read_csv('../65 Years of Weather Data Bangladesh (1948 - 2013).csv')
df.head()
# Out:
#    No Station_Names  YEAR  Month  Max_Temp  Min_Temp  Rainfall  \
# 0   0       Barisal  1949      1      29.4      12.3       0.0
# 1   1       Barisal  1950      1      30.0      14.1       0.0
# 2   2       Barisal  1951      1      28.2      12.3       0.0
# 3   3       Barisal  1952      1      26.6      12.3       2.0
# 4   4       Barisal  1953      1      30.0      13.3      10.0
#
#    Relative_Humidity  Wind_Speed  Cloud_Coverage  Bright_Sunshine  \
# 0               68.0    0.453704             0.6         7.831915
# 1               77.0    0.453704             0.8         7.831915
# 2               77.0    0.453704             0.6         7.831915
# 3               77.0    0.453704             1.0         7.831915
# 4               75.0    0.453704             1.6         7.831915
#
#    Station_Number     X_COR     Y_COR  LATITUDE  LONGITUDE  ALT   Period
# 0           41950  536809.8  510151.9      22.7      90.36    4  1949.01
# 1           41950  536809.8  510151.9      22.7      90.36    4  1950.01
# 2           41950  536809.8  510151.9      22.7      90.36    4  1951.01
# 3           41950  536809.8  510151.9      22.7      90.36    4  1952.01
# 4           41950  536809.8  510151.9      22.7      90.36    4  1953.01

# %%
# Players to be selected
li = ["Barisal","Bhola","Chandpur","Chuadanga","Dhaka","Faridpur","Ishurdi","Jessore","Khepupara","Khulna","Madaripur","Mongla","Patuakhali","Rajshahi","Tangail"]
 
df_new=df[df.Station_Names.isin(li)]
df_new
# Out:
#           No Station_Names  YEAR  Month  Max_Temp  Min_Temp  Rainfall  \
# 0          0       Barisal  1949      1      29.4      12.3       0.0
# 1          1       Barisal  1950      1      30.0      14.1       0.0
# 2          2       Barisal  1951      1      28.2      12.3       0.0
# 3          3       Barisal  1952      1      26.6      12.3       2.0
# 4          4       Barisal  1953      1      30.0      13.3      10.0
# ...      ...           ...   ...    ...       ...       ...       ...
# 20671  20671       Tangail  2009     12      29.2      12.6       0.0
# 20672  20672       Tangail  2010     12      29.7      13.0      62.0
# 20673  20673       Tangail  2011     12      31.0      13.5       0.0
# 20674  20674       Tangail  2012     12      27.6      12.9       1.0
# 20675  20675       Tangail  2013     12      30.3      13.3       2.0
#
#        Relative_Humidity  Wind_Speed  Cloud_Coverage  Bright_Sunshine  \
# 0                   68.0    0.453704             0.6         7.831915
# 1                   77.0    0.453704             0.8         7.831915
# 2                   77.0    0.453704             0.6         7.831915
# 3                   77.0    0.453704             1.0         7.831915
# 4                   75.0    0.453704             1.6         7.831915
# ...                  ...         ...             ...              ...
# 20671               83.0    1.700000             0.7         4.000000
# 20672               80.0    1.800000             1.3         6.200000
# 20673               84.0    1.800000             2.3         4.700000
# 20674               86.0    1.900000             1.6         3.700000
# 20675               82.0    1.700000             0.8         4.700000
#
#        Station_Number      X_COR     Y_COR  LATITUDE  LONGITUDE  ALT   Period
# 0               41950  536809.80  510151.9     22.70      90.36    4  1949.01
# 1               41950  536809.80  510151.9     22.70      90.36    4  1950.01
# 2               41950  536809.80  510151.9     22.70      90.36    4  1951.01
# 3               41950  536809.80  510151.9     22.70      90.36    4  1952.01
# 4               41950  536809.80  510151.9     22.70      90.36    4  1953.01
# ...               ...        ...       ...       ...        ...  ...      ...
# 20671           41909  491982.91  683166.0     24.15      89.55   10  2009.12
# 20672           41909  491982.91  683166.0     24.15      89.55   10  2010.12
# 20673           41909  491982.91  683166.0     24.15      89.55   10  2011.12
# 20674           41909  491982.91  683166.0     24.15      89.55   10  2012.12
# 20675           41909  491982.91  683166.0     24.15      89.55   10  2013.12
#
# [8640 rows x 18 columns]

# %%
df_new=df_new.drop(labels=["No","Station_Names","YEAR","Month","ALT","Station_Number"], axis=1)
df_new.head()
# Out:
#    Max_Temp  Min_Temp  Rainfall  Relative_Humidity  Wind_Speed  \
# 0      29.4      12.3       0.0               68.0    0.453704
# 1      30.0      14.1       0.0               77.0    0.453704
# 2      28.2      12.3       0.0               77.0    0.453704
# 3      26.6      12.3       2.0               77.0    0.453704
# 4      30.0      13.3      10.0               75.0    0.453704
#
#    Cloud_Coverage  Bright_Sunshine     X_COR     Y_COR  LATITUDE  LONGITUDE  \
# 0             0.6         7.831915  536809.8  510151.9      22.7      90.36
# 1             0.8         7.831915  536809.8  510151.9      22.7      90.36
# 2             0.6         7.831915  536809.8  510151.9      22.7      90.36
# 3             1.0         7.831915  536809.8  510151.9      22.7      90.36
# 4             1.6         7.831915  536809.8  510151.9      22.7      90.36
#
#     Period
# 0  1949.01
# 1  1950.01
# 2  1951.01
# 3  1952.01
# 4  1953.01

# %%
z = df_new["Wind_Speed"]

df_new = df_new.drop(labels=["Wind_Speed","X_COR","Y_COR","Bright_Sunshine"], axis=1)
df_new['Wind_Speed'] = z
df_new.head()
# Out:
#    Max_Temp  Min_Temp  Rainfall  Relative_Humidity  Cloud_Coverage  LATITUDE  \
# 0      29.4      12.3       0.0               68.0             0.6      22.7
# 1      30.0      14.1       0.0               77.0             0.8      22.7
# 2      28.2      12.3       0.0               77.0             0.6      22.7
# 3      26.6      12.3       2.0               77.0             1.0      22.7
# 4      30.0      13.3      10.0               75.0             1.6      22.7
#
#    LONGITUDE   Period  Wind_Speed
# 0      90.36  1949.01    0.453704
# 1      90.36  1950.01    0.453704
# 2      90.36  1951.01    0.453704
# 3      90.36  1952.01    0.453704
# 4      90.36  1953.01    0.453704

# %%
X = df_new.iloc[:,:-1]
Y = df_new.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(X, Y, test_size = 0.2)

# %%
# Standard Scaler

from sklearn.preprocessing import StandardScaler

sc=StandardScaler()
scaler = sc.fit(trainX)
trainX_scaled = scaler.transform(trainX)
testX_scaled = scaler.transform(testX)

# %%
from xgboost import XGBRegressor

RegModel=XGBRegressor(max_depth=3, learning_rate=0.1, n_estimators=500, objective='reg:linear', booster='gbtree')
XGB=RegModel.fit(trainX_scaled,trainY)
prediction=XGB.predict(testX_scaled)
# Out:
# [20:17:39] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
df_temp = pd.DataFrame({'Actual': testY, 'Predicted': prediction})
df_temp.head()
# Out:
#        Actual  Predicted
# 844       0.3   0.158197
# 10490     3.1   3.099313
# 12243     0.3   1.332235
# 12152     1.6   1.748009
# 5659      2.3   2.356023

# %%
#Measuring Goodness of fit in Training data
from sklearn import metrics
print('R2 Value:',metrics.r2_score(testY, prediction))

print('Mean Absolute Error:', metrics.mean_absolute_error(testY, prediction))  
print('Mean Squared Error:', metrics.mean_squared_error(testY, prediction))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(testY, prediction)))
# Out:
# R2 Value: 0.7361795471722665
# Mean Absolute Error: 0.3449674912388198
# Mean Squared Error: 0.2538898333509871
# Root Mean Squared Error: 0.5038748191277146
